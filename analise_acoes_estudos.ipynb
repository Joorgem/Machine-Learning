# %% [markdown]
# ## Projeto - Análise de dados de ações - Soluções

# %% [markdown]
# #### Leitura de dados com yfinance

# %% [markdown]
# https://pypi.org/project/yfinance/

# %%
import yfinance as yf
from datetime import datetime, timedelta
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
petr = yf.Ticker("PETR4.SA")

# %%
petr.history(period="max")
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2000-01-03 00:00:00-02:00   1.402440   1.402440   1.402440   1.402440
# 2000-01-04 00:00:00-02:00   1.324858   1.324858   1.324858   1.324858
# 2000-01-05 00:00:00-02:00   1.311490   1.311490   1.311490   1.311490
# 2000-01-06 00:00:00-02:00   1.306955   1.306955   1.306955   1.306955
# 2000-01-07 00:00:00-02:00   1.312923   1.312923   1.312923   1.312923
# ...                              ...        ...        ...        ...
# 2024-06-11 00:00:00-03:00  36.762603  36.947338  36.461189  36.616756
# 2024-06-12 00:00:00-03:00  36.950001  37.049999  35.610001  35.820000
# 2024-06-13 00:00:00-03:00  35.900002  36.189999  34.849998  35.459999
# 2024-06-14 00:00:00-03:00  35.490002  35.500000  34.150002  34.680000
# 2024-06-17 00:00:00-03:00   0.000000  34.810001  34.810001  34.810001
#
#                                 Volume  Dividends  Stock Splits
# Date
# 2000-01-03 00:00:00-02:00  35389440000   0.000000           0.0
# 2000-01-04 00:00:00-02:00  28861440000   0.000000           0.0
# 2000-01-05 00:00:00-02:00  43033600000   0.000000           0.0
# 2000-01-06 00:00:00-02:00  34055680000   0.000000           0.0
# 2000-01-07 00:00:00-02:00  20912640000   0.000000           0.0
# ...                                ...        ...           ...
# 2024-06-11 00:00:00-03:00     31131300   0.000000           0.0
# 2024-06-12 00:00:00-03:00     52182400   1.043242           0.0
# 2024-06-13 00:00:00-03:00     46233500   0.000000           0.0
# 2024-06-14 00:00:00-03:00     53534900   0.000000           0.0
# 2024-06-17 00:00:00-03:00            0   0.000000           0.0
#
# [6141 rows x 7 columns]

# %%
petr.history(period="max")["Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# get stock info
petr.info

# get historical market data
hist = petr.history(period="max")

# show actions (dividends, splits)
petr.actions

# show dividends
petr.dividends

# show splits
petr.splits
# Out:
# Date
# 2005-09-01 00:00:00-03:00    4.0
# 2008-04-28 00:00:00-03:00    2.0
# Name: Stock Splits, dtype: float64

# %%
today = datetime.today().strftime('%Y-%m-%d')
today_minus_7 = (datetime.today() - timedelta(days=7)).strftime('%Y-%m-%d')
data = petr.history(interval='1m', start=today_minus_7, end=today)

# %%
tickers = yf.Tickers('PETR4.SA ABEV3.SA AMER3.SA')
# ^ returns a named tuple of Ticker objects

# %%
tickers.tickers
# Out:
# {'PETR4.SA': yfinance.Ticker object <PETR4.SA>,
#  'ABEV3.SA': yfinance.Ticker object <ABEV3.SA>,
#  'AMER3.SA': yfinance.Ticker object <AMER3.SA>}

# %%
tickers.tickers["PETR4.SA"]
tickers.tickers["PETR4.SA"].info
# Out:
# {'address1': 'Avenida Henrique Valadares, 28',
#  'address2': '19th floor',
#  'city': 'Rio de Janeiro',
#  'state': 'RJ',
#  'zip': '20241-030',
#  'country': 'Brazil',
#  'website': 'https://petrobras.com.br',
#  'industry': 'Oil & Gas Integrated',
#  'industryKey': 'oil-gas-integrated',
#  'industryDisp': 'Oil & Gas Integrated',
#  'sector': 'Energy',
#  'sectorKey': 'energy',
#  'sectorDisp': 'Energy',
#  'longBusinessSummary': 'Petróleo Brasileiro S.A. - Petrobras explores, produces, and sells oil and gas in Brazil and internationally. The company operates through three segments: Exploration and Production; Refining, Transportation and Marketing; and Gas and Power. The Exploration and Production segment explores, develops, and produces crude oil, natural gas liquids, and natural gas primarily for supplies to the domestic refineries. The Refining, Transportation and Marketing segment engages in the refining, logistics, transport, acquisition, and exports of crude oil; and production of fertilizers, as well as holding interests in petrochemical companies. The Gas and Power segment is involved in the logistic and trading of natural gas and electricity; transportation and trading of LNG; generation of electricity through thermoelectric power plants; renewable energy businesses; low carbon services; and natural gas processing business, as well as production of biodiesel and its co-products. The company also engages in prospecting, drilling, refining, processing, trading, and transporting crude oil from producing onshore and offshore oil fields, and shale or other rocks, as well as oil products, natural gas, and other liquid hydrocarbons. In addition, it engages in research, development, production, transport, distribution, and trading of energy. Petróleo Brasileiro S.A. - Petrobras was incorporated in 1953 and is headquartered in Rio de Janeiro, Brazil.',
#  'fullTimeEmployees': 46730,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Ms. Magda Maria de Regina Chambriard',
#    'title': 'CEO & Non-Independent Director',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Clarice  Coppetti',
#    'age': 59,
#    'title': 'Interim President, Chief Corporate Affairs Officer & Member of Executive Board',
#    'yearBorn': 1964,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Carlos Alberto Rechelo Neto',
#    'age': 45,
#    'title': 'Interim CFO & Investor Relations Officer',
#    'yearBorn': 1978,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Mario Vinicius Claussen Spinelli',
#    'age': 52,
#    'title': 'Chief Governance & Compliance Officer and Member of Executive Board',
#    'yearBorn': 1971,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Joelson Falcao Mendes',
#    'age': 59,
#    'title': 'Chief Exploration & Production Officer and Member of Executive Board',
#    'yearBorn': 1964,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Carlos Jose do Nascimento Travassos',
#    'age': 55,
#    'title': 'Chief Engineering, Technology & Innovation Officer and Member of Executive Board',
#    'yearBorn': 1968,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Claudio Romeo Schlosser',
#    'age': 59,
#    'title': 'Chief Logistics, Commercialization & Markets Officer and Member of Executive Board',
#    'yearBorn': 1964,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. William Franca da Silva',
#    'age': 63,
#    'title': 'Chief Industrial Processes & Products Officer and Member of Executive Board',
#    'yearBorn': 1960,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Mauricio Tiomno Tolmasquim',
#    'age': 65,
#    'title': 'Chief Energy Transition & Sustainability Officer and Member of Executive Board',
#    'yearBorn': 1958,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Hélio Siqueira Júnior',
#    'title': 'Acting General Counsel',
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 3,
#  'boardRisk': 5,
#  'compensationRisk': 1,
#  'shareHolderRightsRisk': 9,
#  'overallRisk': 2,
#  'governanceEpochDate': 1717200000,
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 34.81,
#  'dayLow': 34.81,
#  'dayHigh': 34.81,
#  'regularMarketPreviousClose': 34.81,
#  'regularMarketDayLow': 34.81,
#  'regularMarketDayHigh': 34.81,
#  'dividendRate': 5.34,
#  'dividendYield': 0.1534,
#  'exDividendDate': 1718150400,
#  'payoutRatio': 0.5257,
#  'fiveYearAvgDividendYield': 17.97,
#  'beta': 1.007,
#  'trailingPE': 3.771398,
#  'forwardPE': 4.384131,
#  'averageVolume': 42534806,
#  'averageVolume10days': 38124980,
#  'averageDailyVolume10Day': 38124980,
#  'marketCap': 462600536064,
#  'fiftyTwoWeekLow': 27.95,
#  'fiftyTwoWeekHigh': 42.94,
#  'priceToSalesTrailing12Months': 0.94283783,
#  'fiftyDayAverage': 38.9582,
#  'twoHundredDayAverage': 37.5293,
#  'trailingAnnualDividendRate': 5.416,
#  'trailingAnnualDividendYield': 0.15558746,
#  'currency': 'BRL',
#  'enterpriseValue': 678852296704,
#  'profitMargins': 0.2245,
#  'floatShares': 7971356038,
#  'sharesOutstanding': 5453660160,
#  'heldPercentInsiders': 0.16070999,
#  'heldPercentInstitutions': 0.34849998,
#  'impliedSharesOutstanding': 13289299968,
#  'bookValue': 31.577,
#  'priceToBook': 1.1023847,
#  'lastFiscalYearEnd': 1703980800,
#  'nextFiscalYearEnd': 1735603200,
#  'mostRecentQuarter': 1711843200,
#  'earningsQuarterlyGrowth': -0.379,
#  'netIncomeToCommon': 110150000640,
#  'trailingEps': 9.23,
#  'forwardEps': 7.94,
#  'pegRatio': -0.63,
#  'lastSplitFactor': '2:1',
#  'lastSplitDate': 1209340800,
#  'enterpriseToRevenue': 1.384,
#  'enterpriseToEbitda': 2.93,
#  '52WeekChange': 0.1386981,
#  'SandP52WeekChange': 0.24711585,
#  'lastDividendValue': 1.043242,
#  'lastDividendDate': 1718150400,
#  'exchange': 'SAO',
#  'quoteType': 'EQUITY',
#  'symbol': 'PETR4.SA',
#  'underlyingSymbol': 'PETR4.SA',
#  'shortName': 'PETROBRAS   PN  EDJ N2',
#  'longName': 'Petróleo Brasileiro S.A. - Petrobras',
#  'firstTradeDateEpochUtc': 946900800,
#  'timeZoneFullName': 'America/Sao_Paulo',
#  'timeZoneShortName': 'BRT',
#  'uuid': 'f698f172-aeef-3c5e-887d-d45f94bdd057',
#  'messageBoardId': 'finmb_409268',
#  'gmtOffSetMilliseconds': -10800000,
#  'currentPrice': 34.81,
#  'targetHighPrice': 49.0,
#  'targetLowPrice': 26.0,
#  'targetMeanPrice': 41.36,
#  'targetMedianPrice': 43.0,
#  'recommendationMean': 2.4,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 11,
#  'totalCash': 81761001472,
#  'totalCashPerShare': 6.334,
#  'ebitda': 231689994240,
#  'totalDebt': 308954988544,
#  'quickRatio': 0.745,
#  'currentRatio': 1.079,
#  'totalRevenue': 490646994944,
#  'debtToEquity': 75.369,
#  'revenuePerShare': 37.768,
# 2024-06-10 00:00:00-03:00  32560900   0.000000           0.0
# 2024-06-11 00:00:00-03:00  31131300   0.000000           0.0
# 2024-06-12 00:00:00-03:00  52182400   1.043242           0.0
# 2024-06-13 00:00:00-03:00  46233500   0.000000           0.0
# 2024-06-14 00:00:00-03:00  53534900   0.000000           0.0
# 2024-06-17 00:00:00-03:00         0   0.000000           0.0

# %% [markdown]
# ### Ibovespa
# https://www.b3.com.br/pt_br/market-data-e-indices/indices/indices-amplos/indice-ibovespa-ibovespa-composicao-da-carteira.htm

# %%
df_ibov = pd.read_csv("IBOVDia_09-08-22.csv")
df_ibov
# Out:
#    Código          Ação        Tipo  Qtde. Teórica Part. (%)
# 0   RRRP3  3R PETROLEUM  ON      NM    200.372.163     0,341
# 1   ALPA4    ALPARGATAS  PN      N1    201.257.220     0,193
# 2   ABEV3     AMBEV S/A          ON  4.380.195.841     3,214
# 3   AMER3    AMERICANAS  ON      NM    596.875.824     0,421
# 4   ASAI3         ASSAI  ON      NM    794.531.367     0,682
# ..    ...           ...         ...            ...       ...
# 85  VALE3          VALE  ON      NM  3.768.748.489    12,817
# 86  VIIA3           VIA  ON      NM  1.596.295.753     0,231
# 87  VBBR3         VIBRA  ON      NM  1.131.883.365     1,016
# 88  WEGE3           WEG  ON      NM  1.484.859.030     2,189
# 89  YDUQ3    YDUQS PART  ON      NM    300.833.122     0,231
#
# [90 rows x 5 columns]

# %% [markdown]
# #### 1. Vamos analisar o histórico das 10 ações com maior participacão na bolsa. Encontre estes ativos no DataFrame `df_ibov` e carregue-os em um objeto Tickers do módulo do Yahoo.

# %%
acoes = df_ibov.sort_values("Part. (%)").tail(10)["Código"].values

# %%
# my_list = ["how", "are", "you"]
# " ".join(my_list)
# how are you

# %%
string_acoes = " ".join([i + ".SA" for i in acoes])

# %%
tickers = yf.Tickers(string_acoes)

# %%
tickers.tickers
# Out:
# {'WEGE3.SA': yfinance.Ticker object <WEGE3.SA>,
#  'RENT3.SA': yfinance.Ticker object <RENT3.SA>,
#  'ELET3.SA': yfinance.Ticker object <ELET3.SA>,
#  'BBAS3.SA': yfinance.Ticker object <BBAS3.SA>,
#  'ABEV3.SA': yfinance.Ticker object <ABEV3.SA>,
#  'B3SA3.SA': yfinance.Ticker object <B3SA3.SA>,
#  'BBDC4.SA': yfinance.Ticker object <BBDC4.SA>,
#  'PETR3.SA': yfinance.Ticker object <PETR3.SA>,
#  'ITUB4.SA': yfinance.Ticker object <ITUB4.SA>,
#  'PETR4.SA': yfinance.Ticker object <PETR4.SA>}

# %% [markdown]
# #### 2. Crie um dicionário que conterá como chaves os tickers de cada ativo (PETR4.SA, por exemplo) e como valores um DataFrame contendo os dados históricos de cada

# %%
dict_data = {}

for ticker in tickers.tickers.keys():
    print("Baixando dados da {}".format(ticker))
    dict_data[ticker] = tickers.tickers[ticker].history(period="max")
# Out:
# Baixando dados da WEGE3.SA
# Baixando dados da RENT3.SA
# Baixando dados da ELET3.SA
# Baixando dados da BBAS3.SA
# Baixando dados da ABEV3.SA
# Baixando dados da B3SA3.SA
# Baixando dados da BBDC4.SA
# Baixando dados da PETR3.SA
# Baixando dados da ITUB4.SA
# Baixando dados da PETR4.SA

# %% [markdown]
# #### 3. Combine todos os dados em um único DataFrame, utilizando o preço de fechamento de cada ativo.

# %%
df_data = pd.DataFrame()
for ticker in dict_data.keys():
    df_aux = dict_data[ticker].rename(columns={"Close": ticker})
    df_data = df_data.join(df_aux[ticker], how = "outer")

# %%
df_data
# Out:
#                             WEGE3.SA   RENT3.SA   ELET3.SA   BBAS3.SA  \
# Date
# 2000-01-03 00:00:00-02:00   0.120674        NaN   8.875167   0.518579
# 2000-01-04 00:00:00-02:00   0.116440        NaN   8.446089   0.493914
# 2000-01-05 00:00:00-02:00   0.116440        NaN   8.784833   0.498974
# 2000-01-06 00:00:00-02:00   0.105854        NaN   8.581585   0.505930
# 2000-01-07 00:00:00-02:00   0.105854        NaN   8.717085   0.494547
# ...                              ...        ...        ...        ...
# 2024-06-12 00:00:00-03:00  38.070000  41.020000  35.590000  26.337137
# 2024-06-13 00:00:00-03:00  38.419998  40.180000  35.580002  26.515760
# 2024-06-14 00:00:00-03:00  38.770000  40.419998  35.689999  26.450001
# 2024-06-17 00:00:00-03:00  38.770000  39.400002  35.139999  26.450001
# 2024-06-18 00:00:00-03:00        NaN        NaN        NaN        NaN
#
#                             ABEV3.SA  B3SA3.SA   BBDC4.SA   PETR3.SA  \
# Date
# 2000-01-03 00:00:00-02:00        NaN       NaN        NaN   1.369073
# 2000-01-04 00:00:00-02:00        NaN       NaN        NaN   1.292237
# 2000-01-05 00:00:00-02:00   0.290351       NaN        NaN   1.309699
# 2000-01-06 00:00:00-02:00   0.275633       NaN        NaN   1.299222
# 2000-01-07 00:00:00-02:00   0.275633       NaN        NaN   1.309699
# ...                              ...       ...        ...        ...
# 2024-06-12 00:00:00-03:00  11.270000     10.40  12.303473  37.509998
# 2024-06-13 00:00:00-03:00  11.090000     10.08  12.313169  37.020000
# 2024-06-14 00:00:00-03:00  11.240000     10.37  12.439209  36.630001
# 2024-06-17 00:00:00-03:00  11.240000     10.56  12.574944  36.650002
# 2024-06-18 00:00:00-03:00        NaN       NaN        NaN        NaN
#
#                             ITUB4.SA   PETR4.SA
# Date
# 2000-01-03 00:00:00-02:00        NaN   1.402440
# 2000-01-04 00:00:00-02:00        NaN   1.324858
# 2000-01-05 00:00:00-02:00        NaN   1.311490
# 2000-01-06 00:00:00-02:00        NaN   1.306955
# 2000-01-07 00:00:00-02:00        NaN   1.312922
# ...                              ...        ...
# 2024-06-12 00:00:00-03:00  31.500000  35.820000
# 2024-06-13 00:00:00-03:00  31.170000  35.459999
# 2024-06-14 00:00:00-03:00  31.139999  34.680000
# 2024-06-17 00:00:00-03:00  31.900000  34.810001
# 2024-06-18 00:00:00-03:00        NaN        NaN
#
# [6142 rows x 10 columns]

# %% [markdown]
# #### 4. Qual a primeira data na qual todos os ativos estudados já estavam na bolsa?

# %%
df_data.dropna().index[0]
# Out:
# Timestamp('2008-01-02 00:00:00-0200', tz='America/Sao_Paulo')

# %% [markdown]
# #### 5. Crie um DataFrame adicional para representar a variação percentual diária de cada ativo

# %%
df_ret = df_data / df_data.shift(1) - 1

# %% [markdown]
# #### 6. Quais foram as datas na qual cada ativo apresentou sua pior oscilação? Apresente também a variação percentual.

# %%
df_ret.idxmin()
# Out:
# WEGE3.SA   2020-03-16 00:00:00-03:00
# RENT3.SA   2020-03-16 00:00:00-03:00
# ELET3.SA   2010-02-01 00:00:00-02:00
# BBAS3.SA   2016-03-15 00:00:00-03:00
# ABEV3.SA   2005-04-04 00:00:00-03:00
# B3SA3.SA   2011-05-09 00:00:00-03:00
# BBDC4.SA   2009-05-29 00:00:00-03:00
# PETR3.SA   2020-03-09 00:00:00-03:00
# ITUB4.SA   2021-10-04 00:00:00-03:00
# PETR4.SA   2020-03-09 00:00:00-03:00
# dtype: datetime64[ns, America/Sao_Paulo]

# %%
df_ret.min()
# Out:
# WEGE3.SA   -0.206197
# RENT3.SA   -0.234218
# ELET3.SA   -0.220074
# BBAS3.SA   -0.211712
# ABEV3.SA   -0.224263
# B3SA3.SA   -0.661336
# BBDC4.SA   -0.432507
# PETR3.SA   -0.296758
# ITUB4.SA   -0.179643
# PETR4.SA   -0.296978
# dtype: float64

# %% [markdown]
# #### 7. Analisando esta série temporal, você conseguira estimar avaliar se existe uma maior probabilidade maior dos ativos performarem bem logo após um dia de queda?

# %%
df_ret[df_ret.shift(1) < 0].mean()
# Out:
# WEGE3.SA    0.001177
# RENT3.SA    0.001137
# ELET3.SA   -0.000058
# BBAS3.SA    0.000518
# ABEV3.SA    0.001076
# B3SA3.SA    0.001183
# BBDC4.SA    0.000694
# PETR3.SA    0.000396
# ITUB4.SA    0.000442
# PETR4.SA    0.000592
# dtype: float64

# %%
df_study = df_ret[df_ret.shift(1) < 0]

fig, ax = plt.subplots(figsize=(20, 8))
sns.histplot(df_study, kde=True)

print("Média dos retornos")
for acao in acoes:
    print('{} - {}'.format(acao, df_study[acao + '.SA'].mean()*100))
    
print("Desvio padrão dos retornos")
for acao in acoes:
    print('{} - {}'.format(acao, df_study[acao + '.SA'].std()*100))
# Out:
# Média dos retornos
# WEGE3 - 0.11771584322427346
# RENT3 - 0.11374072906643908
# ELET3 - -0.005780247444382507
# BBAS3 - 0.0518486912582361
# ABEV3 - 0.10759806148863732
# B3SA3 - 0.118306329683072
# BBDC4 - 0.06940426153370471
# PETR3 - 0.03963284133006755
# ITUB4 - 0.04417386585771964
# PETR4 - 0.05917821679519963
# Desvio padrão dos retornos
# WEGE3 - 2.1362384797294474
# RENT3 - 2.707698750702109
# ELET3 - 3.079814350768512
# BBAS3 - 2.787120954959355
# ABEV3 - 1.8349731101526485
# B3SA3 - 2.8528026848152073
# BBDC4 - 2.4359456161862507
# PETR3 - 2.899726569217733
# ITUB4 - 2.288266395220076
# PETR4 - 2.8490674189382297

# %% [markdown]
# ##### Percebe-se que tendo a zero, ou seja, não existe correlação nessa hipótese. Comprar uma ação que caiu, não necessariamente irá gerar um retorno positivo.

# %% [markdown]
# #### 8. Seguindo a lógica da questão anterior, avalie como em média se comportam as ações no pregão seguinte a quedas maiores que 1%. De posse destes dados, você acredita que seria uma boa estratégia de investimento comprar ações que cairam no dia anterior?

# %%
df_study = df_ret[df_ret.shift(1) < -0.01]

fig, ax = plt.subplots(figsize=(20, 8))
sns.histplot(df_study, kde=True)

print("Média dos retornos")
for acao in acoes:
    print('{} - {}'.format(acao, df_study[acao + '.SA'].mean()*100))
    
print("Desvio padrão dos retornos")
for acao in acoes:
    print('{} - {}'.format(acao, df_study[acao + '.SA'].std()*100))
# Out:
# Média dos retornos
# WEGE3 - 0.16085585587029677
# RENT3 - 0.12790743404142885
# ELET3 - 0.010240197376033247
# BBAS3 - 0.09140194472775201
# ABEV3 - 0.1983886841612519
# B3SA3 - 0.13517874013881132
# BBDC4 - 0.12870612926237104
# PETR3 - 0.013745699630072196
# ITUB4 - 0.06001482568081558
# PETR4 - 0.01511435577627358
# Desvio padrão dos retornos
# WEGE3 - 2.3156972690860087
# RENT3 - 2.934642639035384
# ELET3 - 3.2974068071640725
# BBAS3 - 3.057162450303202
# ABEV3 - 2.117388426248463
# B3SA3 - 3.1333104295785312
# BBDC4 - 2.7057840760721468
# PETR3 - 3.0994508001542
# ITUB4 - 2.518322099425332
# PETR4 - 3.0651216439421636

# %% [markdown]
# ## DESAFIOS

# %% [markdown]
# #### 9. De tempos em tempos, empresas podem distribuir lucro aos acionistas na forma de dividendos. Podemos obter o histórico de pagamentos de dividendos usando a yfinance. Um indicador muito utilizado no mercado é o Dividend Yield (DY), que é calculado somando-se o total pago de dividendos no ano e dividindo pela cotação da ação. Calcule o DY anual de cada ativo.

# %%
df_dividends = pd.DataFrame()

for ticker in tickers.tickers.keys():
    df_dividends_aux = tickers.tickers[ticker].dividends.to_frame().rename(columns={"Dividends": ticker})
    df_dividends = df_dividends.join(df_dividends_aux, how = 'outer')

# %%
df_dividends['year'] = df_dividends.index.year
df_data['year'] = df_data.index.year

# %%
df_dividends_year = df_dividends.groupby('year').sum()
df_last_price = df_data.dropna().groupby('year').last()

# %%
df_last_price
# Out:
#        WEGE3.SA   RENT3.SA   ELET3.SA   BBAS3.SA   ABEV3.SA   B3SA3.SA  \
# year
# 2008   1.350611   1.569646  11.884452   2.785147   1.947184   3.617771
# 2009   2.042161   4.203813  17.668957   5.677707   3.567347   7.449725
# 2010   2.466076   6.076607  11.895777   6.551015   5.252920   8.087691
# 2011   2.188397   5.860229   9.953323   5.301821   6.789852   2.087475
# 2012   3.224915   8.684642   3.847114   6.134077  10.789708   3.093370
# 2022  1.374214  2.554934   1.868406   7.871163   5.524417  3.722792
# 2023  1.682027  2.384883   0.526328   6.769948   5.318281  2.669426
# 2024  0.917483  0.973470   1.149124   3.702431   0.000000  2.082121
#
#        BBDC4.SA   PETR3.SA  ITUB4.SA   PETR4.SA
# year
# 2008   5.572464   0.519142  0.000000   4.901432
# 2009   4.030702   8.250060  0.000000  10.333446
# 2010   4.413248   8.138350  1.372840  10.432658
# 2011   6.135604  12.146719  6.519506  14.443778
# 2012   4.809524   7.711781  5.733653   8.461625
# 2013   4.897946   2.506467  5.030673   7.302783
# 2014   5.898084  16.147051  4.389404  29.210716
# 2015  10.786949   0.000000  8.415892   0.000000
# 2016   6.509874   0.000000  6.596388   0.000000
# 2017   5.037700   0.000000  4.746373   0.000000
# 2018   3.929265   2.818357  7.011725  11.734871
# 2019   6.962324   4.387129  5.912737   8.775379
# 2020   3.127509   2.306865  2.904417   0.004572
# 2021   6.198279  41.695805  4.921536  45.389254
# 2022   3.152914  83.005393  4.450336  88.097380
# 2023   9.125393  20.699183  3.859837  21.767916
# 2024   4.046976  10.829940  4.617006  11.402723

# %%
df_yield.mean()
# Out:
# WEGE3.SA     2.129480
# RENT3.SA     2.090752
# ELET3.SA     8.368009
# BBAS3.SA     9.312624
# ABEV3.SA     4.321378
# B3SA3.SA     4.078326
# BBDC4.SA     5.566750
# PETR3.SA    13.009544
# ITUB4.SA     4.498960
# PETR4.SA    16.015208
# dtype: float64

# %%
df_yield.mean().mean()
# Out:
# 6.939103158751811

# %% [markdown]
# #### 10. Avalie o desempenho de uma estratégia de investimento que monta uma carteira de ações ano a ano com as 3 maiores pagadoras de dividendo do ano anterior. Compare o desempenho dela com o desempenho de uma carteira global.

# %%
df_ret_year = df_last_price /df_last_price.shift(1) - 1

# %%
((df_ret_year / 10).sum(axis=1) + 1).cumprod().plot()
# Out:
# <Axes: xlabel='year'>

# %%
df_yield.iloc[0, :].nlargest(3).index
# Out:
# Index(['RENT3.SA', 'BBDC4.SA', 'ABEV3.SA'], dtype='object')

# %%
strategy_return = []

for i in range(len(df_yield) - 1):
    stocks = df_yield.iloc[i,:].nlargest(3).index
    strategy_return += [(df_ret_year[stocks].iloc[i + 1] / 3).sum() + 1]

# %%
strategy_return
# Out:
# [1.8142045890579404,
#  0.7310401852387217,
#  0.8213024186842558,
#  0.9854382789968925,
#  1.0515052820454767,
#  0.9038114141591942,
#  0.7489059838933447,
#  1.5611261914857444,
#  1.3248037431501796,
#  1.383561108563444,
#  1.2233373058135735,
#  0.8503568957252559,
#  0.8649657233037573,
#  1.384996078282062,
#  1.8175872245914513,
#  0.9432236126005081]

# %%
df_global = df_ret_year / 10

fig, ax = plt.subplots()
pd.DataFrame(strategy_return, index=df_global.index[1:]).cumprod().plot(color="red", ax=ax)
(df_global.sum(axis=1) + 1).cumprod().plot(color="blue", ax=ax)
# Out:
# <Axes: xlabel='year'>
